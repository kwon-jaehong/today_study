# %%
import pandas as pd

df = pd.read_csv('./train_sample.csv')
df
# Out:
#               id                       img_path  \
# 0    TRAIN_00000  ./image/train/TRAIN_00000.jpg
# 1    TRAIN_00001  ./image/train/TRAIN_00001.jpg
# 2    TRAIN_00002  ./image/train/TRAIN_00002.jpg
# 3    TRAIN_00003  ./image/train/TRAIN_00003.jpg
# 4    TRAIN_00004  ./image/train/TRAIN_00004.jpg
# ..           ...                            ...
# 901  TRAIN_00901  ./image/train/TRAIN_00901.jpg
# 902  TRAIN_00902  ./image/train/TRAIN_00902.jpg
# 903  TRAIN_00903  ./image/train/TRAIN_00903.jpg
# 904  TRAIN_00904  ./image/train/TRAIN_00904.jpg
# 905  TRAIN_00905  ./image/train/TRAIN_00905.jpg
#
#                                               overview          cat1    cat2  \
# 0    소안항은 조용한 섬으로 인근해안이 청정해역으로 일찍이 김 양식을 해서 높은 소득을 ...            자연   자연관광지
# 1    경기도 이천시 모가면에 있는 골프장으로 대중제 18홀이다. 회원제로 개장을 했다가 ...           레포츠  육상 레포츠
# 2    금오산성숯불갈비는 한우고기만을 전문적으로 취급하고 사용하는 부식 자재 또한 유기농법...            음식     음식점
# 3    철판 위에서 요리하는 안동찜닭을 맛볼 수 있는 곳이다. 경상북도 안동시에 있는 한식...            음식     음식점
# 4    ※ 영업시간 10:30 ~ 20:30\n\n3대에 걸쳐 아귀만을 전문으로 취급하는 ...            음식     음식점
# ..                                                 ...           ...     ...
# 901  민주인권기념관은 서울 용산구 남영동에 있었던 공권력의 고문 시설 치안본부(경찰청의 ...  인문(문화/예술/역사)    문화시설
# 902  유교를 집대성한 성인 공자를 비롯하여 옛 성현들의 위패를 모시고 제사를 드리는 사당...  인문(문화/예술/역사)   역사관광지
# 903  고기를 가져오는 곳이 경상북도 자인면이며, 뭉텅뭉텅 자른 한우 생고기를 경상도 사투...            음식     음식점
# 904  한국 미식 프로그램에 자주 소개되는 서울식 불고기를 판매하는 곳이다. 대표메뉴는 불...            음식     음식점
# 905  서상은 전라북도 장수군과 인접하고 있어 시장일에는 전라도에서 많은 장꾼과 사람들이 ...            쇼핑      쇼핑
#
#         cat3
# 0      항구/포구
# 1         골프
# 2         한식
# 3         한식
# 4         한식
# ..       ...
# 901      기념관
# 902  유적지/사적지
# 903       한식
# 904       한식
# 905      5일장
#
# [906 rows x 6 columns]

# %%
# df['cat3'].value_counts().plot.pie(autopct='%.2f')

# %%
# from imblearn.under_sampling import RandomUnderSampler
# # X = df.drop(['cat3'],axis=1)
# X = df
# y = df['cat3']
# rus = RandomUnderSampler(sampling_strategy=0.5)
# x_res,y_res = rus.fit_resample(X,y)
# # ax = y_res.value_counts().plot.pie(autopct='%.2f')

# %%
# x_res
# x_res['cat3'].value_counts()

# %%
from imblearn.over_sampling import RandomOverSampler
# X = df.drop(['cat3'],axis=1)
X = df
y = df['cat3']
rus = RandomOverSampler(random_state=0)
x_res,y_res = rus.fit_resample(X,y)
# ax = y_res.value_counts().plot.pie(autopct='%.2f')
# x_res
x_res['cat3'].value_counts()

# %%
from imblearn.combine
